# %% [markdown]
# <a href="https://colab.research.google.com/github/noman13bd/ML-Learning/blob/master/L1_mean_median_mod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

incomes = np.random.normal(50000, 1000, 1000)
incomes
# Out:
# array([52067.66851173, 51205.4814998 , 50063.58764389, 51917.03425019,
#        48915.54136889, 49794.36539734, 49997.22750288, 49118.86143671,
#        50586.49442764, 50262.05292196, 50708.72958073, 49166.32768894,
#        50078.97872995, 49673.63411725, 50472.73561467, 51021.36873849,
#        49049.77485215, 50601.01867856, 49992.30128971, 50175.54381418,
#        49219.56168718, 49601.39782234, 49490.73141659, 50926.5114041 ,
#        50777.84442433, 50144.74554649, 49738.37454186, 50630.94156562,
#        50763.09761762, 49161.36545296, 51158.30815022, 50064.06094275,
#        50795.9291815 , 48148.45247669, 50069.68107141, 51367.11092553,
#        50719.94107201, 48599.04865266, 49619.1784703 , 50532.03699256,
#        50313.79121772, 49570.7386882 , 49463.16053793, 50474.48803813,
#        48881.43303859, 49685.48890957, 52069.98419421, 51459.48625192,
#        48598.58771119, 49915.29743557, 49007.92491625, 49475.79430869,
# ...

# %%
np.mean(incomes)
# Out:
# 49960.846912407455

# %%
import matplotlib.pyplot as plt
plt.hist(incomes, 10)
plt.show()
